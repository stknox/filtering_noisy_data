# %% [markdown]
# ##### Jupyter Notebook, Step 1 - Benchmarking
# - build pipeline to perform a naive fit for each of the base model classes:
# 	- logistic regression
# 	- decision tree
# 	- k nearest neighbors
# 	- support vector classifier
# - in order to do this, you will need to set a high `C` value in order to perform minimal regularization, in the case of logistic regression and support vector classifier.  An example is 1E10

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline
from tqdm import tqdm
import pickle
from sklearn.pipeline import Pipeline

UCIsample1_clean = pickle.load( open( "UCIsample1_clean", "rb" ) )
UCIsample2_clean = pickle.load( open( "UCIsample2_clean", "rb" ) )
UCIsample3_clean = pickle.load( open( "UCIsample3_clean", "rb" ) )
DBsample1_clean = pickle.load( open( "DBsample1_clean", "rb" ) )
DBsample2_clean = pickle.load( open( "DBsample2_clean", "rb" ) )
DBsample3_clean = pickle.load( open( "DBsample3_clean", "rb" ) )

UCIsample1 = pickle.load( open( "UCIsample1", "rb" ) )
UCIsample2 = pickle.load( open( "UCIsample2", "rb" ) )
UCIsample3 = pickle.load( open( "UCIsample3", "rb" ) )
DBsample1 = pickle.load( open( "DBsample1", "rb" ) )
DBsample2 = pickle.load( open( "DBsample2", "rb" ) )
DBsample3 = pickle.load( open( "DBsample3", "rb" ) )

sample_list = [UCIsample1_clean, UCIsample2_clean, UCIsample3_clean, \
               DBsample1_clean, DBsample2_clean, DBsample3_clean]
sample_names = ['UCIsample1_clean', 'UCIsample2_clean', 'UCIsample3_clean', \
                'DBsample1_clean', 'DBsample2_clean', 'DBsample3_clean']
sample_list_noise = [UCIsample1, UCIsample2, UCIsample3, \
               DBsample1, DBsample2, DBsample3]
sample_names_noise = ['UCIsample1', 'UCIsample2', 'UCIsample3', \
                'DBsample1', 'DBsample2', 'DBsample3']

UCIsample1_clean.name = 'UCIsample1_clean'
UCIsample2_clean.name = 'UCIsample2_clean'
UCIsample3_clean.name = 'UCIsample3_clean'
DBsample1_clean.name = 'DBsample1_clean' 
DBsample2_clean.name = 'DBsample2_clean' 
DBsample3_clean.name = 'DBsample3_clean'
UCIsample1.name = 'UCIsample1'
UCIsample2.name = 'UCIsample2'
UCIsample3.name = 'UCIsample3'
DBsample1.name = 'DBsample1' 
DBsample2.name = 'DBsample2' 
DBsample3.name = 'DBsample3'

# %%
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC, LinearSVC

logr = LogisticRegression(C=1E10)
dct = DecisionTreeClassifier()
knn = KNeighborsClassifier()
svcp = SVC(C=1E10)

logr_scaled = make_pipeline(StandardScaler(), LogisticRegression(C=1E10))
dct_scaled = make_pipeline(StandardScaler(), DecisionTreeClassifier())
knn_scaled = make_pipeline(StandardScaler(), KNeighborsClassifier())
svcp_scaled = make_pipeline(StandardScaler(), SVC(C=1E10))

pipe_names = ['logr', 'dct', 'knn', 'svcp', 'logr_scaled', 'dct_scaled', 'knn_scaled', 'svcp_scaled']
pipe_list = [logr, dct, knn, svcp, logr_scaled, dct_scaled, knn_scaled, svcp_scaled]
model_zip = list(zip(pipe_names, pipe_list))

# %%
from sklearn.metrics import (precision_score, 
                             accuracy_score, 
                             roc_auc_score, 
                             roc_curve, 
                             precision_recall_curve, 
                             recall_score,
                             make_scorer,
                             auc,
                             classification_report,
                             confusion_matrix
                            )

# %%
# expected ratios based on targets

# first calculate the average label values:
DB_mean = (DBsample1_clean['target'].mean() + DBsample2_clean['target'].mean() + DBsample3_clean['target'].mean())/3
UCI_mean = (UCIsample1_clean[500].mean() + UCIsample2_clean[500].mean() + UCIsample3_clean[500].mean())/3

# since the values range from -1 to 1 in UCI, we need to scale it to correct the ratio by adding 1 and dividing by 2
display("Label ratio in DB is", DB_mean)
display("Label ratio in UCI is",(UCI_mean + 1)/2)

# confirming that this matches the accuracy score averaged across samples:
benchmark_all_1_1000 = np.array([1]*1000)
benchmark_all_1_200 = np.array([1]*200)

display("accuracy in DB is", (
        accuracy_score(DBsample1_clean['target'], benchmark_all_1_1000) + 
        accuracy_score(DBsample2_clean['target'], benchmark_all_1_1000) + 
        accuracy_score(DBsample3_clean['target'], benchmark_all_1_1000))
        /3)

display("accuracy in UCI is", (
        accuracy_score(UCIsample1_clean[500], benchmark_all_1_200) +
        accuracy_score(UCIsample2_clean[500], benchmark_all_1_200) +
        accuracy_score(UCIsample3_clean[500], benchmark_all_1_200))
        /3)
# Out:
# 'Label ratio in DB is'
# 0.49033333333333334
# 'Label ratio in UCI is'
# 0.52333333333333332
# 'accuracy in DB is'
# 0.49033333333333334
# 'accuracy in UCI is'
# 0.52333333333333343

# %%
# define a function to loop through each sample and each pipeline and output the results to a dataframe.  first, 
# doing this with the noisy features

def score_pipelines(sample_list, model_zip):
    results = []
    for sample in tqdm(sample_list):
        y = sample.iloc[:,-1]
        X = sample.iloc[:,0:-1]
        X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)
        for model_name, model in model_zip:
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            recall = recall_score(y_test, y_pred)
            precision = precision_score(y_test, y_pred)
#             class_report = classification_report(y_test, y_pred)
#             conf_matrix = confusion_matrix(y_test, y_pred)
            results.append({
                    'sample':sample.name,
                    'name':'{}'.format(model_name),
                    'model':model,
                    'train_accuracy' : model.score(X_train, y_train),
                    'test_accuracy': model.score(X_test, y_test),
                    'recall':recall,
                    'precision':precision,
#                     'classification_report':class_report,
#                     'conf_matrix':conf_matrix
            })
    return pd.DataFrame(results)

results = score_pipelines(sample_list_noise, model_zip)
display(results.sort_values('test_accuracy', ascending=False))
# Out:
#  33%|███▎      | 2/6 [00:00<00:01,  3.92it/s]/opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 100%|██████████| 6/6 [00:26<00:00,  4.40s/it]
#                                                 model         name  precision  \
# 10  KNeighborsClassifier(algorithm='auto', leaf_si...          knn   0.642857
# 35  SVC(C=10000000000.0, cache_size=200, class_wei...         svcp   0.629630
# 42  KNeighborsClassifier(algorithm='auto', leaf_si...          knn   0.635593
# 2   KNeighborsClassifier(algorithm='auto', leaf_si...          knn   0.636364
# 27  SVC(C=10000000000.0, cache_size=200, class_wei...         svcp   0.580882
# 29  Pipeline(steps=[('standardscaler', StandardSca...   dct_scaled   0.574627
# 43  SVC(C=10000000000.0, cache_size=200, class_wei...         svcp   0.600000
# 33  DecisionTreeClassifier(class_weight=None, crit...          dct   0.573770
# 37  Pipeline(steps=[('standardscaler', StandardSca...   dct_scaled   0.576271
# 25  DecisionTreeClassifier(class_weight=None, crit...          dct   0.573913
# 0   LogisticRegression(C=10000000000.0, class_weig...         logr   0.620690
# 14  Pipeline(steps=[('standardscaler', StandardSca...   knn_scaled   0.560000
# 26  KNeighborsClassifier(algorithm='auto', leaf_si...          knn   0.553957
# 31  Pipeline(steps=[('standardscaler', StandardSca...  svcp_scaled   0.556452
# 9   DecisionTreeClassifier(class_weight=None, crit...          dct   0.538462
# 21  Pipeline(steps=[('standardscaler', StandardSca...   dct_scaled   0.689655
# 45  Pipeline(steps=[('standardscaler', StandardSca...   dct_scaled   0.556338
# 3   SVC(C=10000000000.0, cache_size=200, class_wei...         svcp   0.560000
# 34  KNeighborsClassifier(algorithm='auto', leaf_si...          knn   0.536765
# 36  Pipeline(steps=[('standardscaler', StandardSca...  logr_scaled   0.538462
# 40  LogisticRegression(C=10000000000.0, class_weig...         logr   0.547619
# 13  Pipeline(steps=[('standardscaler', StandardSca...   dct_scaled   0.518519
# 39  Pipeline(steps=[('standardscaler', StandardSca...  svcp_scaled   0.532710
# 7   Pipeline(steps=[('standardscaler', StandardSca...  svcp_scaled   0.586207
# 18  KNeighborsClassifier(algorithm='auto', leaf_si...          knn   0.678571
# 32  LogisticRegression(C=10000000000.0, class_weig...         logr   0.528455
# 41  DecisionTreeClassifier(class_weight=None, crit...          dct   0.534247
# 44  Pipeline(steps=[('standardscaler', StandardSca...  logr_scaled   0.540323
# 47  Pipeline(steps=[('standardscaler', StandardSca...  svcp_scaled   0.544643
# 46  Pipeline(steps=[('standardscaler', StandardSca...   knn_scaled   0.531250
# 4   Pipeline(steps=[('standardscaler', StandardSca...  logr_scaled   0.576923
# 6   Pipeline(steps=[('standardscaler', StandardSca...   knn_scaled   0.562500
# 24  LogisticRegression(C=10000000000.0, class_weig...         logr   0.500000
# 30  Pipeline(steps=[('standardscaler', StandardSca...   knn_scaled   0.496454
# 28  Pipeline(steps=[('standardscaler', StandardSca...  logr_scaled   0.495868
# 8   LogisticRegression(C=10000000000.0, class_weig...         logr   0.483871
# 5   Pipeline(steps=[('standardscaler', StandardSca...   dct_scaled   0.560000
# 17  DecisionTreeClassifier(class_weight=None, crit...          dct   0.629630
# 11  SVC(C=10000000000.0, cache_size=200, class_wei...         svcp   0.480000
# 38  Pipeline(steps=[('standardscaler', StandardSca...   knn_scaled   0.456522
# 16  LogisticRegression(C=10000000000.0, class_weig...         logr   0.625000
# 1   DecisionTreeClassifier(class_weight=None, crit...          dct   0.520000
# 22  Pipeline(steps=[('standardscaler', StandardSca...   knn_scaled   0.608696
# 20  Pipeline(steps=[('standardscaler', StandardSca...  logr_scaled   0.583333
# 23  Pipeline(steps=[('standardscaler', StandardSca...  svcp_scaled   0.611111
# 15  Pipeline(steps=[('standardscaler', StandardSca...  svcp_scaled   0.400000
# 12  Pipeline(steps=[('standardscaler', StandardSca...  logr_scaled   0.392857
# 19  SVC(C=10000000000.0, cache_size=200, class_wei...         svcp   0.000000
#
#       recall      sample  test_accuracy  train_accuracy
# 10  0.750000  UCIsample2          0.680        0.813333
# 35  0.557377   DBsample2          0.624        1.000000
# 42  0.595238   DBsample3          0.624        0.758667
# 2   0.750000  UCIsample1          0.620        0.753333
# 27  0.647541   DBsample1          0.600        1.000000
# 29  0.631148   DBsample1          0.592        1.000000
# 43  0.547619   DBsample3          0.588        1.000000
# 33  0.573770   DBsample2          0.584        1.000000
# 37  0.557377   DBsample2          0.584        1.000000
# 25  0.540984   DBsample1          0.580        1.000000
# 0   0.642857  UCIsample1          0.580        1.000000
# 14  0.583333  UCIsample2          0.580        0.660000
# 26  0.631148   DBsample1          0.572        0.742667
# 31  0.565574   DBsample1          0.568        1.000000
# 9   0.583333  UCIsample2          0.560        1.000000
# 21  0.606061  UCIsample3          0.560        1.000000
# 45  0.626984   DBsample3          0.560        1.000000
# 3   1.000000  UCIsample1          0.560        1.000000
# 34  0.598361   DBsample2          0.552        0.774667
# 36  0.516393   DBsample2          0.548        1.000000
# 40  0.547619   DBsample3          0.544        1.000000
# 13  0.583333  UCIsample2          0.540        1.000000
# 39  0.467213   DBsample2          0.540        1.000000
# 7   0.607143  UCIsample1          0.540        1.000000
# 18  0.575758  UCIsample3          0.540        0.780000
# 32  0.532787   DBsample2          0.540        1.000000
# 41  0.619048   DBsample3          0.536        1.000000
# 44  0.531746   DBsample3          0.536        1.000000
# 47  0.484127   DBsample3          0.536        1.000000
# 46  0.539683   DBsample3          0.528        0.712000
# 4   0.535714  UCIsample1          0.520        1.000000
# 6   0.642857  UCIsample1          0.520        0.700000
# 24  0.508197   DBsample1          0.512        1.000000
# 30  0.573770   DBsample1          0.508        0.710667
# 28  0.491803   DBsample1          0.508        1.000000
# 8   0.625000  UCIsample2          0.500        1.000000
# 5   0.500000  UCIsample1          0.500        1.000000
# 17  0.515152  UCIsample3          0.480        1.000000
# 11  1.000000  UCIsample2          0.480        1.000000
# 38  0.516393   DBsample2          0.464        0.708000
# 16  0.454545  UCIsample3          0.460        1.000000
# 1   0.464286  UCIsample1          0.460        1.000000
# 22  0.424242  UCIsample3          0.440        0.740000
# 20  0.424242  UCIsample3          0.420        1.000000
# 23  0.333333  UCIsample3          0.420        1.000000
# 15  0.500000  UCIsample2          0.400        1.000000
# 12  0.458333  UCIsample2          0.400        1.000000
# 19  0.000000  UCIsample3          0.340        1.000000

# %%
# second, running this on the noiseless features (our core 20).  overall better test accuracy, but still overfitting
# on the train set and not doing fantastically well.

results = score_pipelines(sample_list, model_zip)
display(results.sort_values('test_accuracy', ascending=False))
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]/opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 100%|██████████| 6/6 [00:11<00:00,  1.94s/it]
#                                                 model         name  precision  \
# 7   Pipeline(steps=[('standardscaler', StandardSca...  svcp_scaled   0.875000
# 14  Pipeline(steps=[('standardscaler', StandardSca...   knn_scaled   0.740741
# 34  KNeighborsClassifier(algorithm='auto', leaf_si...          knn   0.773913
# 15  Pipeline(steps=[('standardscaler', StandardSca...  svcp_scaled   0.750000
# 10  KNeighborsClassifier(algorithm='auto', leaf_si...          knn   0.714286
# 38  Pipeline(steps=[('standardscaler', StandardSca...   knn_scaled   0.765217
# 30  Pipeline(steps=[('standardscaler', StandardSca...   knn_scaled   0.721805
# 26  KNeighborsClassifier(algorithm='auto', leaf_si...          knn   0.718519
# 42  KNeighborsClassifier(algorithm='auto', leaf_si...          knn   0.762712
# 46  Pipeline(steps=[('standardscaler', StandardSca...   knn_scaled   0.746032
# 2   KNeighborsClassifier(algorithm='auto', leaf_si...          knn   0.857143
# 27  SVC(C=10000000000.0, cache_size=200, class_wei...         svcp   0.723577
# 35  SVC(C=10000000000.0, cache_size=200, class_wei...         svcp   0.745455
# 31  Pipeline(steps=[('standardscaler', StandardSca...  svcp_scaled   0.722689
# 25  DecisionTreeClassifier(class_weight=None, crit...          dct   0.720339
# 29  Pipeline(steps=[('standardscaler', StandardSca...   dct_scaled   0.698413
# 43  SVC(C=10000000000.0, cache_size=200, class_wei...         svcp   0.714286
# 33  DecisionTreeClassifier(class_weight=None, crit...          dct   0.702479
# 37  Pipeline(steps=[('standardscaler', StandardSca...   dct_scaled   0.691057
# 22  Pipeline(steps=[('standardscaler', StandardSca...   knn_scaled   0.800000
# 23  Pipeline(steps=[('standardscaler', StandardSca...  svcp_scaled   0.821429
# 47  Pipeline(steps=[('standardscaler', StandardSca...  svcp_scaled   0.700787
# 6   Pipeline(steps=[('standardscaler', StandardSca...   knn_scaled   0.782609
# 39  Pipeline(steps=[('standardscaler', StandardSca...  svcp_scaled   0.693694
# 21  Pipeline(steps=[('standardscaler', StandardSca...   dct_scaled   0.766667
# 13  Pipeline(steps=[('standardscaler', StandardSca...   dct_scaled   0.629630
# 9   DecisionTreeClassifier(class_weight=None, crit...          dct   0.629630
# 41  DecisionTreeClassifier(class_weight=None, crit...          dct   0.648855
# 18  KNeighborsClassifier(algorithm='auto', leaf_si...          knn   0.741935
# 17  DecisionTreeClassifier(class_weight=None, crit...          dct   0.741935
# 45  Pipeline(steps=[('standardscaler', StandardSca...   dct_scaled   0.622951
# 40  LogisticRegression(C=10000000000.0, class_weig...         logr   0.619469
# 44  Pipeline(steps=[('standardscaler', StandardSca...  logr_scaled   0.619469
# 16  LogisticRegression(C=10000000000.0, class_weig...         logr   0.809524
# 5   Pipeline(steps=[('standardscaler', StandardSca...   dct_scaled   0.642857
# 24  LogisticRegression(C=10000000000.0, class_weig...         logr   0.585366
# 28  Pipeline(steps=[('standardscaler', StandardSca...  logr_scaled   0.585366
# 36  Pipeline(steps=[('standardscaler', StandardSca...  logr_scaled   0.583333
# 32  LogisticRegression(C=10000000000.0, class_weig...         logr   0.583333
# 1   DecisionTreeClassifier(class_weight=None, crit...          dct   0.629630
# 20  Pipeline(steps=[('standardscaler', StandardSca...  logr_scaled   0.772727
# 0   LogisticRegression(C=10000000000.0, class_weig...         logr   0.652174
# 3   SVC(C=10000000000.0, cache_size=200, class_wei...         svcp   0.560000
# 4   Pipeline(steps=[('standardscaler', StandardSca...  logr_scaled   0.619048
# 12  Pipeline(steps=[('standardscaler', StandardSca...  logr_scaled   0.500000
# 8   LogisticRegression(C=10000000000.0, class_weig...         logr   0.484848
# 11  SVC(C=10000000000.0, cache_size=200, class_wei...         svcp   0.480000
# 19  SVC(C=10000000000.0, cache_size=200, class_wei...         svcp   0.000000
#
#       recall            sample  test_accuracy  train_accuracy
# 7   0.750000  UCIsample1_clean          0.800        1.000000
# 14  0.833333  UCIsample2_clean          0.780        0.860000
# 34  0.729508   DBsample2_clean          0.764        0.821333
# 15  0.750000  UCIsample2_clean          0.760        1.000000
# 10  0.833333  UCIsample2_clean          0.760        0.806667
# 38  0.721311   DBsample2_clean          0.756        0.813333
# 30  0.786885   DBsample1_clean          0.748        0.833333
# 26  0.795082   DBsample1_clean          0.748        0.818667
# 42  0.714286   DBsample3_clean          0.744        0.832000
# 46  0.746032   DBsample3_clean          0.744        0.836000
# 2   0.642857  UCIsample1_clean          0.740        0.820000
# 27  0.729508   DBsample1_clean          0.732        1.000000
# 35  0.672131   DBsample2_clean          0.728        1.000000
# 31  0.704918   DBsample1_clean          0.724        1.000000
# 25  0.696721   DBsample1_clean          0.720        1.000000
# 29  0.721311   DBsample1_clean          0.712        1.000000
# 43  0.714286   DBsample3_clean          0.712        1.000000
# 33  0.696721   DBsample2_clean          0.708        1.000000
# 37  0.696721   DBsample2_clean          0.700        1.000000
# 22  0.727273  UCIsample3_clean          0.700        0.926667
# 23  0.696970  UCIsample3_clean          0.700        1.000000
# 47  0.706349   DBsample3_clean          0.700        1.000000
# 6   0.642857  UCIsample1_clean          0.700        0.820000
# 39  0.631148   DBsample2_clean          0.684        1.000000
# 21  0.696970  UCIsample3_clean          0.660        1.000000
# 13  0.708333  UCIsample2_clean          0.660        1.000000
# 9   0.708333  UCIsample2_clean          0.660        1.000000
# 41  0.674603   DBsample3_clean          0.652        1.000000
# 18  0.696970  UCIsample3_clean          0.640        0.886667
# 17  0.696970  UCIsample3_clean          0.640        1.000000
# 45  0.603175   DBsample3_clean          0.616        1.000000
# 40  0.555556   DBsample3_clean          0.604        0.617333
# 44  0.555556   DBsample3_clean          0.604        0.617333
# 16  0.515152  UCIsample3_clean          0.600        0.606667
# 5   0.642857  UCIsample1_clean          0.600        1.000000
# 24  0.590164   DBsample1_clean          0.596        0.597333
# 28  0.590164   DBsample1_clean          0.596        0.597333
# 36  0.516393   DBsample2_clean          0.584        0.609333
# 32  0.516393   DBsample2_clean          0.584        0.609333
# 1   0.607143  UCIsample1_clean          0.580        1.000000
# 20  0.515152  UCIsample3_clean          0.580        0.646667
# 0   0.535714  UCIsample1_clean          0.580        0.706667
# 3   1.000000  UCIsample1_clean          0.560        1.000000
# 4   0.464286  UCIsample1_clean          0.540        0.700000
# 12  0.708333  UCIsample2_clean          0.520        0.660000
# 8   0.666667  UCIsample2_clean          0.500        0.653333
# 11  1.000000  UCIsample2_clean          0.480        1.000000
# 19  0.000000  UCIsample3_clean          0.340        1.000000

# %% [markdown]
# There is a serious amount of overfitting going on in the benchmark models, especially in the samples with the noise (all 500 or 1000 features) compared to the ones that have had Josh's first-pass noise-reduction run on them.  The models, as a result, are only a little better than a coin flip at predicting an outcome on the test split (for most of them).
#
# Of these, KNN and SVC seem to perform the best, getting as high as 70-ish percent in many of the test splits.  On some models, however, SVC often gets worse than a coin flip, giving it high variance

# %%
112000*0.07*(40-10)
# Out:
# 235200.00000000003

# %%
112000*1.07
# Out:
# 119840.0
