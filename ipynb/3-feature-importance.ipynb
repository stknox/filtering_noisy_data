# %% [markdown]
# ##### Jupyter Notebook, Step 3 - Testing Model Pipelines
# - Considering these results, develop a strategy for building a final predictive model
# - recommended approaches:
#     - Use feature selection to reduce the dataset to a manageable size then use conventional methods
#     - Use dimension reduction to reduce the dataset to a manageable size then use conventional methods
#     - Use an iterative model training method to use the entire dataset
# - This notebook should be a "playground" where you try various approaches to solving this problem

# %% [markdown]
# We've already used Josh's method to reduce the noise out of the dataset as part of EDA, and have subsequently run feature selection to identify a few features for each data set that seem to be the most valuable.  Additionally, we ran PCA to narrow down to 5 features, which was successful.  Thus, we're doing a version of part 2 above - doing dimension reduction by removing noise, followed by further dimension reduction in PCA (going from 20->5 features).  Conventional methods then follow, including our baseline models and *******.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline
from tqdm import tqdm
import pickle
from sklearn.pipeline import Pipeline


UCIsample1_clean = pickle.load( open( "UCIsample1_clean", "rb" ) )
UCIsample2_clean = pickle.load( open( "UCIsample2_clean", "rb" ) )
UCIsample3_clean = pickle.load( open( "UCIsample3_clean", "rb" ) )
DBsample1_clean = pickle.load( open( "DBsample1_clean", "rb" ) )
DBsample2_clean = pickle.load( open( "DBsample2_clean", "rb" ) )
DBsample3_clean = pickle.load( open( "DBsample3_clean", "rb" ) )

UCIsample1 = pickle.load( open( "UCIsample1", "rb" ) )
UCIsample2 = pickle.load( open( "UCIsample2", "rb" ) )
UCIsample3 = pickle.load( open( "UCIsample3", "rb" ) )
DBsample1 = pickle.load( open( "DBsample1", "rb" ) )
DBsample2 = pickle.load( open( "DBsample2", "rb" ) )
DBsample3 = pickle.load( open( "DBsample3", "rb" ) )

sample_list = [UCIsample1_clean, UCIsample2_clean, UCIsample3_clean, \
               DBsample1_clean, DBsample2_clean, DBsample3_clean]
sample_names = ['UCIsample1_clean', 'UCIsample2_clean', 'UCIsample3_clean', \
                'DBsample1_clean', 'DBsample2_clean', 'DBsample3_clean']
sample_list_noise = [UCIsample1, UCIsample2, UCIsample3, \
               DBsample1, DBsample2, DBsample3]
sample_names_noise = ['UCIsample1', 'UCIsample2', 'UCIsample3', \
                'DBsample1', 'DBsample2', 'DBsample3']

UCIsample1_clean.name = 'UCIsample1_clean'
UCIsample2_clean.name = 'UCIsample2_clean'
UCIsample3_clean.name = 'UCIsample3_clean'
DBsample1_clean.name = 'DBsample1_clean' 
DBsample2_clean.name = 'DBsample2_clean' 
DBsample3_clean.name = 'DBsample3_clean'
UCIsample1.name = 'UCIsample1'
UCIsample2.name = 'UCIsample2'
UCIsample3.name = 'UCIsample3'
DBsample1.name = 'DBsample1' 
DBsample2.name = 'DBsample2' 
DBsample3.name = 'DBsample3'

DB_features = pickle.load( open('DB_features', "rb" ) )
UCI_features = pickle.load( open('UCI_features', "rb" ) )

from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.model_selection import GridSearchCV, StratifiedShuffleSplit
from sklearn.feature_selection import SelectPercentile, SelectKBest, f_classif
from sklearn.decomposition import PCA
from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier, ExtraTreesClassifier, RandomForestClassifier
from sklearn.metrics import (precision_score, 
                             accuracy_score, 
                             roc_auc_score, 
                             roc_curve, 
                             precision_recall_curve, 
                             recall_score,
                             make_scorer,
                             auc,
                             classification_report,
                             confusion_matrix
                            )

# %%
logr_scaled = Pipeline([
    ('scaling', StandardScaler(with_mean=False)), 
    ('pca', PCA(n_components=5)),
    ('classifier', LogisticRegression())])

dct_scaled = Pipeline([
    ('scaling', StandardScaler(with_mean=False)), 
    ('pca', PCA(n_components=5)),
    ('classifier', DecisionTreeClassifier())])

knn_scaled = Pipeline([
    ('scaling', StandardScaler(with_mean=False)), 
    ('pca', PCA(n_components=5)),
    ('classifier', KNeighborsClassifier())])

svc_scaled = Pipeline([
    ('scaling', StandardScaler(with_mean=False)), 
    ('pca', PCA(n_components=5)),
    ('classifier', SVC())])

logr_params = {
               'classifier__penalty':['l1','l2'], 
               'classifier__C':np.logspace(-3,3,7)}
dct_params = {
#               'classifier__max_features':np.arange(0,5),
              'classifier__max_depth':np.arange(1,8)}
knn_params = {
              'classifier__weights':['uniform','distance'],
              'classifier__n_neighbors':np.arange(3,13,2)}
svc_params = {
               'classifier__gamma':np.logspace(-3,3,7), 
               'classifier__C':np.logspace(-3,3,7),
               'classifier__kernel':['rbf','sigmoid']}

logr_scaled_gs = GridSearchCV(logr_scaled, logr_params, cv=StratifiedShuffleSplit(n_splits=5, test_size = .2))
dct_scaled_gs = GridSearchCV(dct_scaled, dct_params, cv=StratifiedShuffleSplit(n_splits=5, test_size = .2))
knn_scaled_gs = GridSearchCV(knn_scaled, knn_params, cv=StratifiedShuffleSplit(n_splits=5, test_size = .2))
svc_scaled_gs = GridSearchCV(svc_scaled, svc_params, cv=StratifiedShuffleSplit(n_splits=5, test_size = .2))

# GradientBoostingClassifier - no

ada_scaled = Pipeline([
    ('scaling', StandardScaler(with_mean=False)), 
    ('pca', PCA(n_components=5)),
    ('clf', AdaBoostClassifier(DecisionTreeClassifier(max_depth=1), learning_rate=.5))])

bag_scaled = Pipeline([
    ('scaling', StandardScaler(with_mean=False)), 
    ('pca', PCA(n_components=5)),
    ('clf', BaggingClassifier(DecisionTreeClassifier(random_state=42), max_samples=.8, random_state=42))])

rfc_scaled = Pipeline([
    ('scaling', StandardScaler(with_mean=False)), 
    ('pca', PCA(n_components=5)),
    ('clf',RandomForestClassifier(random_state=42))])

etc_scaled = Pipeline([
    ('scaling', StandardScaler(with_mean=False)), 
    ('pca', PCA(n_components=5)),
    ('clf',ExtraTreesClassifier(random_state=42))])

ada_params = {
              "clf__base_estimator__criterion" : ["gini", "entropy"],
#               "base_estimator__splitter" :   ["best", "random"],
              'clf__n_estimators': [100]}

bag_params = {
    'clf__base_estimator': [DecisionTreeClassifier(max_depth=md, random_state=42) for md in [5,7,10,None]],
    'clf__n_estimators':[10,50,100]}

rfc_params = {
    'clf__n_estimators':[10,50,100,200],
    'clf__max_features':['auto','log2']}

etc_params = {
    'clf__bootstrap':[True, False],
    'clf__n_estimators':[10,50,100,200]}

ada_scaled_gs = GridSearchCV(ada_scaled, ada_params, cv=StratifiedShuffleSplit(n_splits=5, test_size = .2), n_jobs=-1)
bag_gs = GridSearchCV(bag_scaled, bag_params, cv=StratifiedShuffleSplit(n_splits=5, test_size = .2), n_jobs=-1)
rfc_scaled_gs = GridSearchCV(rfc_scaled, rfc_params, cv=StratifiedShuffleSplit(n_splits=5, test_size = .2), n_jobs=-1)
etc_scaled_gs = GridSearchCV(etc_scaled, etc_params, cv=StratifiedShuffleSplit(n_splits=5, test_size = .2), n_jobs=-1)


pipe_names = ['logr_scaled', 'dct_scaled', 'knn_scaled', 'svcp_scaled', 'ada_scaled_gs', 'bag_gs', 'rfc_scaled_gs', 'etc_scaled_gs']
pipe_list = [logr_scaled_gs, dct_scaled_gs, knn_scaled_gs, svc_scaled_gs, ada_scaled_gs, bag_gs, rfc_scaled_gs, etc_scaled_gs]
model_zip = list(zip(pipe_names, pipe_list))

# %%
def score_pipelines(sample_list, model_zip):
    results = []
    for sample in tqdm(sample_list):
        y = sample.iloc[:,-1]
        X = sample.iloc[:,0:-1]
        X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, test_size=0.5)
        for model_name, model in model_zip:
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            recall = recall_score(y_test, y_pred)
            precision = precision_score(y_test, y_pred)
            results.append({
                    'sample': sample.name,
                    'name':'{}'.format(model_name),
                    'model': model,
                    'best_params': model.best_params_,
                    'train_accuracy': model.score(X_train, y_train),
                    'test_accuracy': model.score(X_test, y_test),
                    'recall': recall,
                    'precision': precision,
            })
    return pd.DataFrame(results)

# for sample in sample_list:
#     for pipe in tqdm(pipe_list):
#         display(fit_sample_model(sample, pipe))

results = score_pipelines(sample_list, model_zip)
# Out:
# 100%|██████████| 6/6 [02:42<00:00, 27.13s/it]

# %%
display(results.sort_values('test_accuracy', ascending=False))
# Out:
#                                           best_params  \
# 15  {'clf__bootstrap': False, 'clf__n_estimators':...
# 10  {'classifier__n_neighbors': 3, 'classifier__we...
# 47  {'clf__bootstrap': True, 'clf__n_estimators': ...
# 31  {'clf__bootstrap': False, 'clf__n_estimators':...
# 5   {'clf__base_estimator': DecisionTreeClassifier...
# 2   {'classifier__n_neighbors': 7, 'classifier__we...
# 30  {'clf__max_features': 'auto', 'clf__n_estimato...
# 29  {'clf__base_estimator': DecisionTreeClassifier...
# 26  {'classifier__n_neighbors': 3, 'classifier__we...
# 3   {'classifier__C': 100.0, 'classifier__gamma': ...
# 34  {'classifier__n_neighbors': 5, 'classifier__we...
# 38  {'clf__max_features': 'auto', 'clf__n_estimato...
# 37  {'clf__base_estimator': DecisionTreeClassifier...
# 13  {'clf__base_estimator': DecisionTreeClassifier...
# 39  {'clf__bootstrap': True, 'clf__n_estimators': ...
# 46  {'clf__max_features': 'auto', 'clf__n_estimato...
# 14  {'clf__max_features': 'auto', 'clf__n_estimato...
# 27  {'classifier__C': 1.0, 'classifier__gamma': 0....
# 43  {'classifier__C': 10.0, 'classifier__gamma': 0...
# 11  {'classifier__C': 10.0, 'classifier__gamma': 0...
# 42  {'classifier__n_neighbors': 7, 'classifier__we...
# 35  {'classifier__C': 1000.0, 'classifier__gamma':...
# 45  {'clf__base_estimator': DecisionTreeClassifier...
# 7   {'clf__bootstrap': True, 'clf__n_estimators': ...
# 1                        {'classifier__max_depth': 4}
# 9                        {'classifier__max_depth': 5}
# 6   {'clf__max_features': 'auto', 'clf__n_estimato...
# 18  {'classifier__n_neighbors': 3, 'classifier__we...
# 23  {'clf__bootstrap': False, 'clf__n_estimators':...
# 36  {'clf__base_estimator__criterion': 'entropy', ...
# 33                       {'classifier__max_depth': 7}
# 4   {'clf__base_estimator__criterion': 'gini', 'cl...
# 22  {'clf__max_features': 'auto', 'clf__n_estimato...
# 44  {'clf__base_estimator__criterion': 'gini', 'cl...
# 25                       {'classifier__max_depth': 5}
# 28  {'clf__base_estimator__criterion': 'entropy', ...
# 19  {'classifier__C': 10.0, 'classifier__gamma': 0...
# 40  {'classifier__C': 0.1, 'classifier__penalty': ...
# 0   {'classifier__C': 0.001, 'classifier__penalty'...
# 21  {'clf__base_estimator': DecisionTreeClassifier...
# 32  {'classifier__C': 0.001, 'classifier__penalty'...
# 20  {'clf__base_estimator__criterion': 'gini', 'cl...
# 24  {'classifier__C': 0.1, 'classifier__penalty': ...
# 41                       {'classifier__max_depth': 6}
# 12  {'clf__base_estimator__criterion': 'entropy', ...
# 17                       {'classifier__max_depth': 1}
# 8   {'classifier__C': 0.1, 'classifier__penalty': ...
# 16  {'classifier__C': 0.1, 'classifier__penalty': ...
#
#                                                 model           name  \
# 15  GridSearchCV(cv=StratifiedShuffleSplit(n_split...  etc_scaled_gs
# 10  GridSearchCV(cv=StratifiedShuffleSplit(n_split...     knn_scaled
# 47  GridSearchCV(cv=StratifiedShuffleSplit(n_split...  etc_scaled_gs
# 31  GridSearchCV(cv=StratifiedShuffleSplit(n_split...  etc_scaled_gs
# 5   GridSearchCV(cv=StratifiedShuffleSplit(n_split...         bag_gs
# 2   GridSearchCV(cv=StratifiedShuffleSplit(n_split...     knn_scaled
# 30  GridSearchCV(cv=StratifiedShuffleSplit(n_split...  rfc_scaled_gs
# 29  GridSearchCV(cv=StratifiedShuffleSplit(n_split...         bag_gs
# 26  GridSearchCV(cv=StratifiedShuffleSplit(n_split...     knn_scaled
# 3   GridSearchCV(cv=StratifiedShuffleSplit(n_split...    svcp_scaled
# 34  GridSearchCV(cv=StratifiedShuffleSplit(n_split...     knn_scaled
# 38  GridSearchCV(cv=StratifiedShuffleSplit(n_split...  rfc_scaled_gs
# 37  GridSearchCV(cv=StratifiedShuffleSplit(n_split...         bag_gs
# 13  GridSearchCV(cv=StratifiedShuffleSplit(n_split...         bag_gs
# 39  GridSearchCV(cv=StratifiedShuffleSplit(n_split...  etc_scaled_gs
# 46  GridSearchCV(cv=StratifiedShuffleSplit(n_split...  rfc_scaled_gs
# 14  GridSearchCV(cv=StratifiedShuffleSplit(n_split...  rfc_scaled_gs
# 27  GridSearchCV(cv=StratifiedShuffleSplit(n_split...    svcp_scaled
# 43  GridSearchCV(cv=StratifiedShuffleSplit(n_split...    svcp_scaled
# 11  GridSearchCV(cv=StratifiedShuffleSplit(n_split...    svcp_scaled
# 42  GridSearchCV(cv=StratifiedShuffleSplit(n_split...     knn_scaled
# 35  GridSearchCV(cv=StratifiedShuffleSplit(n_split...    svcp_scaled
# 45  GridSearchCV(cv=StratifiedShuffleSplit(n_split...         bag_gs
# 7   GridSearchCV(cv=StratifiedShuffleSplit(n_split...  etc_scaled_gs
# 1   GridSearchCV(cv=StratifiedShuffleSplit(n_split...     dct_scaled
# 9   GridSearchCV(cv=StratifiedShuffleSplit(n_split...     dct_scaled
# 6   GridSearchCV(cv=StratifiedShuffleSplit(n_split...  rfc_scaled_gs
# 18  GridSearchCV(cv=StratifiedShuffleSplit(n_split...     knn_scaled
# 23  GridSearchCV(cv=StratifiedShuffleSplit(n_split...  etc_scaled_gs
# 36  GridSearchCV(cv=StratifiedShuffleSplit(n_split...  ada_scaled_gs
# 33  GridSearchCV(cv=StratifiedShuffleSplit(n_split...     dct_scaled
# 4   GridSearchCV(cv=StratifiedShuffleSplit(n_split...  ada_scaled_gs
# 22  GridSearchCV(cv=StratifiedShuffleSplit(n_split...  rfc_scaled_gs
# 44  GridSearchCV(cv=StratifiedShuffleSplit(n_split...  ada_scaled_gs
# 25  GridSearchCV(cv=StratifiedShuffleSplit(n_split...     dct_scaled
# 28  GridSearchCV(cv=StratifiedShuffleSplit(n_split...  ada_scaled_gs
# 19  GridSearchCV(cv=StratifiedShuffleSplit(n_split...    svcp_scaled
# 40  GridSearchCV(cv=StratifiedShuffleSplit(n_split...    logr_scaled
# 0   GridSearchCV(cv=StratifiedShuffleSplit(n_split...    logr_scaled
# 21  GridSearchCV(cv=StratifiedShuffleSplit(n_split...         bag_gs
# 32  GridSearchCV(cv=StratifiedShuffleSplit(n_split...    logr_scaled
# 20  GridSearchCV(cv=StratifiedShuffleSplit(n_split...  ada_scaled_gs
# 24  GridSearchCV(cv=StratifiedShuffleSplit(n_split...    logr_scaled
# 41  GridSearchCV(cv=StratifiedShuffleSplit(n_split...     dct_scaled
# 12  GridSearchCV(cv=StratifiedShuffleSplit(n_split...  ada_scaled_gs
# 17  GridSearchCV(cv=StratifiedShuffleSplit(n_split...     dct_scaled
# 8   GridSearchCV(cv=StratifiedShuffleSplit(n_split...    logr_scaled
# 16  GridSearchCV(cv=StratifiedShuffleSplit(n_split...    logr_scaled
#
#     precision    recall            sample  test_accuracy  train_accuracy
# 15   0.690909  0.844444  UCIsample2_clean          0.760           1.000
# 10   0.678571  0.844444  UCIsample2_clean          0.750           1.000
# 47   0.744000  0.746988   DBsample3_clean          0.746           1.000
# 31   0.715827  0.799197   DBsample1_clean          0.742           1.000
# 5    0.826087  0.678571  UCIsample1_clean          0.740           1.000
# 2    0.773585  0.732143  UCIsample1_clean          0.730           1.000
# 30   0.708029  0.779116   DBsample1_clean          0.730           1.000
# 29   0.705036  0.787149   DBsample1_clean          0.730           0.986
# 26   0.702509  0.787149   DBsample1_clean          0.728           1.000
# 3    0.741379  0.767857  UCIsample1_clean          0.720           0.920
# 34   0.723982  0.661157   DBsample2_clean          0.714           0.806
# 38   0.723982  0.661157   DBsample2_clean          0.714           1.000
# 37   0.700405  0.714876   DBsample2_clean          0.714           0.860
# 13   0.666667  0.711111  UCIsample2_clean          0.710           0.960
# 39   0.723502  0.648760   DBsample2_clean          0.710           1.000
# 46   0.704724  0.718876   DBsample3_clean          0.710           1.000
# 14   0.642857  0.800000  UCIsample2_clean          0.710           1.000
# 27   0.672185  0.815261   DBsample1_clean          0.710           0.814
# 43   0.692308  0.722892   DBsample3_clean          0.702           0.914
# 11   0.627119  0.822222  UCIsample2_clean          0.700           1.000
# 42   0.680297  0.734940   DBsample3_clean          0.696           1.000
# 35   0.686695  0.661157   DBsample2_clean          0.690           0.744
# 45   0.678030  0.718876   DBsample3_clean          0.690           0.994
# 7    0.790698  0.607143  UCIsample1_clean          0.690           1.000
# 1    0.820513  0.571429  UCIsample1_clean          0.690           0.890
# 9    0.645833  0.688889  UCIsample2_clean          0.690           0.890
# 6    0.750000  0.642857  UCIsample1_clean          0.680           1.000
# 18   0.714286  0.701754  UCIsample3_clean          0.670           1.000
# 23   0.725490  0.649123  UCIsample3_clean          0.660           1.000
# 36   0.647303  0.644628   DBsample2_clean          0.658           0.790
# 33   0.665116  0.590909   DBsample2_clean          0.658           0.864
# 4    0.684211  0.696429  UCIsample1_clean          0.650           0.970
# 22   0.739130  0.596491  UCIsample3_clean          0.650           1.000
# 44   0.651064  0.614458   DBsample3_clean          0.644           0.784
# 25   0.604863  0.799197   DBsample1_clean          0.640           0.768
# 28   0.611650  0.759036   DBsample1_clean          0.640           0.788
# 19   0.678571  0.666667  UCIsample3_clean          0.630           0.980
# 40   0.630901  0.590361   DBsample3_clean          0.624           0.582
# 0    0.695652  0.571429  UCIsample1_clean          0.620           0.630
# 21   0.704545  0.543860  UCIsample3_clean          0.610           0.970
# 32   0.586777  0.586777   DBsample2_clean          0.600           0.634
# 20   0.660000  0.578947  UCIsample3_clean          0.590           0.980
# 24   0.582090  0.626506   DBsample1_clean          0.590           0.602
# 41   0.592920  0.538153   DBsample3_clean          0.586           0.804
# 12   0.516129  0.711111  UCIsample2_clean          0.570           1.000
# 17   0.740741  0.350877  UCIsample3_clean          0.560           0.670
# 8    0.472222  0.755556  UCIsample2_clean          0.510           0.650
# 16   0.557692  0.508772  UCIsample3_clean          0.490           0.620
